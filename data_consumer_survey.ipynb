# %%
# Import the necessary library we need for our data preparation: pandas package:
import pandas as pd

# %%
# Read in csv file containing data from consumer survey:
survey = pd.read_csv('data/consumer_survey.csv')

# %%
# Show dataframe:
survey
# Out:
#                                              question  \
# 0           Current frequency of buying organic foods
# 1           Current frequency of buying organic foods
# 2           Current frequency of buying organic foods
# 3           Current frequency of buying organic foods
# 4           Current frequency of buying organic foods
# 5           Current frequency of buying organic foods
# 6   Planned frequency of buying organic foods in t...
# 7   Planned frequency of buying organic foods in t...
# 8   Planned frequency of buying organic foods in t...
# 9   Planned frequency of buying organic foods in t...
# 10  Planned frequency of buying organic foods in t...
# 11  Planned frequency of buying organic foods in t...
# 12                   Reasons for buying organic foods
# 13                   Reasons for buying organic foods
# 14                   Reasons for buying organic foods
# 15                   Reasons for buying organic foods
# 16                   Reasons for buying organic foods
# 17                   Reasons for buying organic foods
# 18                   Reasons for buying organic foods
# 19                   Reasons for buying organic foods
# 20                   Reasons for buying organic foods
# 21                   Reasons for buying organic foods
#
#                                               item total age_14_29 age_30_49  \
# 0                                      Exclusively    3%        3%        3%
# 1                                       Frequently   33%       30%       38%
# 2                                     Occasionally   49%       52%       43%
# 3                                            Never   15%       16%       16%
# 4                                            Top 2   36%       33%       41%
# 5                                            Top 3   85%       85%       84%
# 6                                      Exclusively    4%        3%        5%
# 7                                       Frequently   38%       40%       40%
# 8                                     Occasionally   47%       50%       41%
# 9                                            Never   12%        7%       14%
# 10                                           Top 2   42%       43%       45%
# 11                                           Top 3   89%       93%       86%
# 12  Regional origin and support for regional firms   88%       83%       86%
# 13                                  Animal welfare   90%       87%       90%
# 14                       Fewer additive substances   85%       77%       88%
# 15                                    Healthy diet   87%       79%       87%
# 16         No use of genetically changed organisms   74%       68%       69%
# 17                    Contribution to biodiversity   74%       64%       80%
# 18                                           Taste   67%       62%       65%
# 19                 Avoidance of pesticide residues   84%       71%       83%
# 20  Social standards and fair income for producers   79%       76%       76%
# 21                 Products as natural as possible   90%       87%       88%
#
#    age_50_x female male
# 0        3%     4%   3%
# 1       31%    36%  29%
# 2       51%    47%  50%
# 3       15%    12%  18%
# 4       34%    40%  32%
# 5       85%    87%  82%
# 6        4%     5%   3%
# 7       35%    39%  35%
# 8       48%    46%  48%
# 9       12%    10%  14%
# 10      39%    44%  38%
# 11      87%    90%  86%
# 12      91%    91%  85%
# 13      91%    92%  87%
# 14      86%    89%  81%
# 15      89%    90%  83%
# 16      78%    80%  67%
# 17      74%    75%  72%
# 18      69%    70%  63%
# 19      90%    87%  82%
# 20      82%    83%  75%
# 21      92%    90%  89%

# %%
# Show dataframe info:
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   question   22 non-null     object
#  1   item       22 non-null     object
#  2   total      22 non-null     object
#  3   age_14_29  22 non-null     object
#  4   age_30_49  22 non-null     object
#  5   age_50_x   22 non-null     object
#  6   female     22 non-null     object
#  7   male       22 non-null     object
# dtypes: object(8)
# memory usage: 1.5+ KB

# %%
# We have no null values in our dataframe.

# %%
# We now want to upload the dataframe as a database to the server.

# Import sql_functions.py because we need some functions from that module:
import sql_functions as sqlf

# We need to restart the kernel and rerun at this point if we changed the module since we first imported it.

# %%
# Create a variable called engine using the get_engine function:
engine = sqlf.get_engine()

# %%
# We set the schema to our course name:
schema = 'hh_analytics_23_4'

# We set the table_name variable to our group name + the name of the dataframe:
table_name = 'organic_food_consumer_survey'

# %%
# We need psycopg2 for raising possible error message:
import psycopg2

# %%
# Write records stored in the dataframe to SQL database:
if engine!=None:
    try:
        survey.to_sql(name=table_name, # name of SQL table variable
                        con=engine, # engine or connection
                        schema=schema, # our class schema variable
                        if_exists='replace', # Drop the table before inserting new values
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The organic_food_consumer_survey table was imported successfully.

# %%
# Test: query the newly created table to count the rows (we know from above that the dataframe has 22 cases):
sqlf.get_dataframe(f'SELECT COUNT(*) FROM {schema}.organic_food_consumer_survey;')
# Out:
#    count
# 0     22

# %%
# Worked!
