# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#df_market_share_21 = pd.read_excel('market_share_bio_germany_21.xlsx')
df_market_share_21 = pd.read_excel('market_share_bio_germany_21.xlsx', sheet_name='Daten')
#df_sheet2 = pd.read_excel('file.xlsx', sheet_name='Sheet2')

# %%
df_market_share_21= df_market_share_21[4:]

# %%
df_market_share_21
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3
# 4          NaN       2011        4.10       in %
# 5          NaN       2012        4.32       in %
# 6          NaN       2013        4.46       in %
# 7          NaN       2014        4.60       in %
# 8          NaN       2015        4.84       in %
# 9          NaN       2016        4.96       in %
# 10         NaN       2017        5.23       in %
# 11         NaN       2018        5.31       in %
# 12         NaN       2019        5.68       in %
# 13         NaN      2020¹        6.40       in %
# 14         NaN       2021        7.00       in %

# %%
# just keeping the year and value columns
df_market_share_21= df_market_share_21.iloc[:, [1, 2]]

# %%
df_market_share_21.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
# Anteil von Bio-Lebensmitteln am Lebensmittelumsatz in Deutschland in den Jahren 2011 bis 2021
col_names= ["Year", "share in percent"]
df_market_share_21.columns=col_names

# %%
# importing turnover data
turnover_bio_22 = pd.read_excel('turnover_bio_22.xlsx', sheet_name='Daten')

# %%
turnover_bio_22= turnover_bio_22[4:]

# %%
turnover_bio_22= turnover_bio_22.iloc[:, [1,2]]

# %%
#Umsatz mit Bio-Lebensmitteln in Deutschland in den Jahren 2000 bis 2022 (in Milliarden Euro)
col_names= ["Year", "Billion Euros"]
turnover_bio_22.columns = col_names
turnover_bio_22
# Out:
#     Year  Billion Euros
# 4   2000           2.10
# 5   2001           2.70
# 6   2002           3.00
# 7   2003           3.10
# 8   2004           3.50
# 9   2005           3.90
# 10  2006           4.60
# 11  2007           5.30
# 12  2008           5.85
# 13  2009           5.80
# 14  2010           6.02
# 15  2011           6.64
# 16  2012           7.04
# 17  2013           7.42
# 18  2014           7.76
# 19  2015           8.62
# 20  2016           9.84
# 21  2017          10.34
# 22  2018          10.91
# 23  2019          12.26
# 24  2020          14.99
# 25  2021          15.87
# 26  2022          15.31

# %%
turnover_change_bio_germany_22 = pd.read_excel('turnover_change_bio_germany_22.xlsx', sheet_name='Daten')
#turnover_change_bio_germany_22.xlsx

# %%
# turnover change of bio products until 2022
# Umsatzveränderung mit Bio-Lebensmitteln in Deutschland in den Jahren 2001 bis 2022 (gegenüber dem Vorjahr)
turnover_change_bio_germany_22= turnover_change_bio_germany_22[4:].iloc[:, [1,2]]

# %%
col_names= ["Year", "percent_change_to_year_before"]
turnover_change_bio_germany_22.columns= col_names

# %%
turnover_change_bio_germany_22
# Out:
#     Year  percent_change_to_year_before
# 4   2001                           28.6
# 5   2002                           11.1
# 6   2003                            3.3
# 7   2004                           12.9
# 8   2005                           11.4
# 9   2006                           17.9
# 10  2007                           15.2
# 11  2008                           10.4
# 12  2009                           -0.9
# 13  2010                            3.8
# 14  2011                           10.3
# 15  2012                            5.7
# 16  2013                            6.4
# 17  2014                            4.6
# 18  2015                           11.1
# 19  2016                            9.6
# 20  2017                            5.1
# 21  2018                            5.5
# 22  2019                           12.3
# 23  2020                           22.3
# 24  2021                            5.8
# 25  2022                           -3.5

# %%
turnover_bio_international_22 = pd.read_excel('turnover_bio_international_22.xlsx', sheet_name='Daten')
#turnover_bio_international_22.xlsx

# %%
turnover_bio_international_22=turnover_bio_international_22[4:]

# %%
# Umsatz mit Bio-Lebensmitteln weltweit in den Jahren 1999 bis 2021 (in Milliarden Euro)
turnover_bio_international_22 = turnover_bio_international_22.iloc[:, [1,2]]

col_names= ["Year", "Billion Euros"]
turnover_bio_international_22.columns=col_names
turnover_bio_international_22
# Out:
#     Year  Billion Euros
# 4   1999           15.2
# 5   2000           18.0
# 6   2001           20.9
# 7   2002           23.1
# 8   2003           25.5
# 9   2004           28.7
# 10  2005           33.2
# 11  2006           38.6
# 12  2007           46.1
# 13  2008           50.9
# 14  2009           54.1
# 15  2010           59.0
# 16  2011           62.9
# 17  2012           63.8
# 18  2013           72.0
# 19  2014           80.0
# 20  2015           75.7
# 21  2016           84.7
# 22  2017           92.1
# 23  2018           96.7
# 24  2019          106.4
# 25  2020          120.7
# 26  2021          124.8

# %%
# statistic_id284622_umsatz-mit-bio-lebensmitteln-in-deutschland-nach-vertriebsformen-bis-2022
turnover_bio_germany_vertriebsformen = pd.read_excel('turnover_bio_vertriebsformen.xlsx', sheet_name='Daten')

# %%
turnover_bio_germany_vertriebsformen= turnover_bio_germany_vertriebsformen[4:].iloc[:, [1,2,3,4]]

# %%
turnover_bio_germany_vertriebsformen.columns= ["Year", "lm-einzelhandel", "Naturkostfachgeschaefte (inkl. grosser Hoflaeden)", "sonstige"]

# %%
turnover_bio_germany_vertriebsformen
# Out:
#     Year lm-einzelhandel Naturkostfachgeschaefte (inkl. grosser Hoflaeden)  \
# 4   2010            3.26                                              1.88
# 5   2011            3.32                                              2.07
# 6   2012            3.79                                              2.21
# 7   2013            4.06                                              2.26
# 8   2014            4.21                                              2.47
# 9   2015            4.76                                              2.71
# 10  2016            5.45                                              2.85
# 11  2017            5.92                                              2.91
# 12  2018             6.4                                              2.93
# 13  2019            7.42                                              3.18
# 14  2020            9.05                                               3.7
# ...

# %%
#df_market_share_21 = pd.read_excel('market_share_bio_germany_21.xlsx')
expences_germany_2022 = pd.read_excel('expences_germany_2022.xlsx', sheet_name='Daten')

# %%
# bio expences germany until 2022
expences_germany_2022= expences_germany_2022[4:].iloc[:, [1,2]]
#expences_germany_2022.columns=["Year", "Billion Euros"]
#expences_germany_2022

# %%
expences_germany_2022.columns=["Year", "Billion Euros"]
expences_germany_2022
# Out:
#     Year  Billion Euros
# 4   2004            1.7
# 5   2005            2.0
# 6   2006            2.5
# 7   2007            2.9
# 8   2008            3.2
# 9   2009            3.2
# 10  2010            3.3
# 11  2011            3.6
# 12  2012            3.9
# 13  2013            4.1
# 14  2014            4.4
# 15  2015            4.8
# 16  2016            5.1
# 17  2017            5.2
# 18  2018            5.4
# 19  2019            6.1
# 20  2020            6.7
# 21  2021            7.2
# 22  2022            6.9

# %%
turnover_bio_international_22
# Out:
#     Year  Billion Euros
# 4   1999           15.2
# 5   2000           18.0
# 6   2001           20.9
# 7   2002           23.1
# 8   2003           25.5
# 9   2004           28.7
# 10  2005           33.2
# 11  2006           38.6
# 12  2007           46.1
# 13  2008           50.9
# 14  2009           54.1
# 15  2010           59.0
# 16  2011           62.9
# 17  2012           63.8
# 18  2013           72.0
# 19  2014           80.0
# 20  2015           75.7
# 21  2016           84.7
# 22  2017           92.1
# 23  2018           96.7
# 24  2019          106.4
# 25  2020          120.7
# 26  2021          124.8

# %%
# showing the percent change in bar charts
plt.figure(figsize=(10, 6))
plt.bar(turnover_change_bio_germany_22['Year'].astype(str), turnover_change_bio_germany_22['percent_change_to_year_before'], color='#FF0000')
plt.xlabel('Year')
plt.ylabel('Percent Change compared to year before')
plt.title('Percentage Change Over Years(Germany)')
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
turnover_bio_germany_vertriebsformen.columns
# Out:
# Index(['Year', 'lm-einzelhandel',
#        'Naturkostfachgeschaefte (inkl. grosser Hoflaeden)', 'sonstige'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))

bottom = None
for column in turnover_bio_germany_vertriebsformen.columns[1:]:
    if bottom is None:
        plt.bar(turnover_bio_germany_vertriebsformen['Year'].astype(str), turnover_bio_germany_vertriebsformen[column], label=column)
        bottom = turnover_bio_germany_vertriebsformen[column]
    else:
        plt.bar(turnover_bio_germany_vertriebsformen['Year'].astype(str), turnover_bio_germany_vertriebsformen[column], bottom=bottom, label=column)
        bottom += turnover_bio_germany_vertriebsformen[column]

plt.xlabel('Year')
plt.ylabel('Values')
plt.title('Values Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
turnover_bio_international_22.columns
# Out:
# Index(['Year', 'Billion Euros'], dtype='object')

# %%
# turnover_bio_international_22
# showing bio food international turnover over years
plt.figure(figsize=(10, 6))
plt.bar(turnover_bio_international_22['Year'].astype(str), turnover_bio_international_22['Billion Euros'], color='#008080')
plt.xlabel('Year')
plt.ylabel('international bio turnover (Billon Euros)')
plt.title('bio food international turnover over years(international)')
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
turnover_bio_22.columns
# Out:
# Index(['Year', 'Billion Euros'], dtype='object')

# %%
# turnover_bio_22
# showing bio food international turnover over years
plt.figure(figsize=(10, 6))
plt.bar(turnover_bio_22['Year'].astype(str), turnover_bio_22['Billion Euros'], color='green')
plt.xlabel('Year')
plt.ylabel('Organic food sales in Germany (billion euros)')
#plt.title('bio food turnover over years(Germany)')
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
# with increased font size:
plt.figure(figsize=(10, 6))
plt.bar(turnover_bio_22['Year'].astype(str), turnover_bio_22['Billion Euros'], color='green')
plt.xlabel('Year', fontsize=15)  # Increase font size
plt.ylabel('Organic food sales (billion €)', fontsize=16)  # Increase font size
#plt.title('Bio food turnover over years (Germany)', fontsize=17.5)  # Increase font size
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
turnover_bio_22
# Out:
#     Year  Billion Euros
# 4   2000           2.10
# 5   2001           2.70
# 6   2002           3.00
# 7   2003           3.10
# 8   2004           3.50
# 9   2005           3.90
# 10  2006           4.60
# 11  2007           5.30
# 12  2008           5.85
# 13  2009           5.80
# 14  2010           6.02
# 15  2011           6.64
# 16  2012           7.04
# 17  2013           7.42
# 18  2014           7.76
# 19  2015           8.62
# 20  2016           9.84
# 21  2017          10.34
# 22  2018          10.91
# 23  2019          12.26
# 24  2020          14.99
# 25  2021          15.87
# 26  2022          15.31

# %%
expences_germany_2022
# bio food expenditure in germany until 2022 (billion Euros)

plt.figure(figsize=(10, 6))
plt.bar(expences_germany_2022['Year'].astype(str), expences_germany_2022['Billion Euros'], color='#f88379')
plt.xlabel('Year')
plt.ylabel('Percentage bio food Share in germany Compared to the whole market until 2022)')
plt.title('Bio food market share in Germany untill 2022 in percent')
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
expences_germany_2022
expences_germany_2022.to_csv("df_share")
# bio food expenditure in germany until 2022 (billion Euros)

plt.figure(figsize=(10, 6))
plt.bar(expences_germany_2022['Year'].astype(str), expences_germany_2022['Billion Euros'], color='skyblue')

for i, value in enumerate(expences_germany_2022['Billion Euros']):
    plt.text(i, value + 0.1, str(value)+ "%", ha='center')

    
plt.xlabel('Year')
plt.ylabel('Percentage bio food Share in germany Compared to the whole market until 2022)')
plt.title('Bio food market share in Germany untill 2022 in percent')
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
expences_germany_2022= expences_germany_2022[9:]

# %%
expences_germany_2022
# bio food expenditure in germany until 2022 (billion Euros)

plt.figure(figsize=(10, 6))
plt.bar(expences_germany_2022['Year'].astype(str), expences_germany_2022['Billion Euros'], color='skyblue')

for i, value in enumerate(expences_germany_2022['Billion Euros']):
    plt.text(i, value + 0.1, str(value)+ "%", ha='center')

    
plt.xlabel('Year')
plt.ylabel('Percentage bio food Share in germany Compared to the whole market until 2022)')
plt.title('Bio food market share in Germany untill 2022 in percent')
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
# Denns turnover 2008- 2021 (Million Euros)
denns_21 = pd.read_excel("turnover_denns_2000_2021.xlsx", sheet_name="Daten")
denns_21= denns_21[4:].iloc[:, [1,2]]
denns_21.columns=["Year", "value_million_euros"]
denns_21
# Out:
#     Year  value_million_euros
# 4   2008                47.00
# 5   2009                64.00
# 6   2010                69.78
# 7   2011               102.31
# 8   2012               138.62
# 9   2013               186.94
# 10  2014               233.02
# 11  2015               308.83
# 12  2016               354.91
# 13  2017               403.66
# 14  2018               453.38
# 15  2019               515.64
# 16  2020               662.49
# 17  2021               689.07

# %%
# showing Denn's biomarkt turnover from 2008 - 2021
plt.figure(figsize=(10,6))
plt.bar(denns_21["Year"].astype(str), denns_21["value_million_euros"], color="#37ce00")
plt.xlabel("Turnover over years(Denn's biomarkt)")
plt.ylabel("Year")
plt.title("Turnover for Denn's bio Supermarket from 2008 to 2021")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
turnover_biomarkts_germany_21 = pd.read_excel("turnover_biomarkts_germany_21.xlsx", sheet_name="Daten")
turnover_biomarkts_germany_21 = turnover_biomarkts_germany_21[4:].iloc[:, [1,2]]
turnover_biomarkts_germany_21.columns=["Market_name", "Turnover(million euros)"]
turnover_biomarkts_germany_21
# Out:
#                       Market_name  Turnover(million euros)
# 4   Super Natur Markt (Alnatura)²                    634.0
# 5       Denns Biomarkt (Dennree)³                    476.0
# 6                     Bio Company                    240.0
# 7                          Basic¹                    143.0
# 8                  Ebl Naturkost¹                    126.0
# 9                  SuperBioMarkt¹                     97.0
# 10                         Aleco¹                     55.0
# 11           Vollcorner Biomarkt¹                     52.0

# %%
plt.figure(figsize=(10, 6))
plt.bar(turnover_biomarkts_germany_21["Market_name"], turnover_biomarkts_germany_21["Turnover(million euros)"], color="#ffa500")
plt.xlabel("Market names")
plt.ylabel("Turnover in 2021 (Million Euros)")
plt.xticks(rotation=45)
plt.title("Turnover of leading Biomarkets in germany in year 2021")
plt.grid(True)
plt.show()

# %%
inflation= pd.read_csv("inflation_cleaned")
inflation
# Out:
#                    country  2013  2014  2015  2016  2017  2018  2019  2020  \
# 0                  Albania   1.9   1.6   1.9   1.3   2.0   2.0   1.4   1.6
# 1                  Austria   2.1   1.5   0.8   1.0   2.2   2.1   1.5   1.4
# 2                  Belarus  18.3  18.1  13.5  11.8   6.0   4.9   5.6   5.5
# 3                  Belgium   1.2   0.5   0.6   1.8   2.2   2.3   1.3   0.4
# 4   Bosnia and Herzegovina  -0.1  -0.9  -1.0  -1.6   0.8   1.4   0.6  -1.1
# 5                 Bulgaria   0.4  -1.6  -1.1  -1.3   1.2   2.6   2.5   1.2
# 6                  Croatia   2.3   0.2  -0.3  -0.6   1.3   1.6   0.8   0.0
# 7                   Cyprus   0.4  -0.3  -1.5  -1.2   0.7   0.8   0.6  -1.1
# 8           Czech Republic   1.4   0.3   0.3   0.7   2.5   2.1   2.8   3.2
# 9                  Denmark   0.5   0.4   0.2   0.0   1.1   0.7   0.7   0.3
# 10                 Estonia   3.2   0.5   0.1   0.8   3.7   3.4   2.3  -0.6
# ...

# %%
inflation.set_index("country", inplace=True)

# %%
inflation.index
# Out:
# Index(['Albania', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina',
#        'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia',
#        'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Kosovo', 'Lithuania', 'Luxembourg',
#        'Malta', 'Moldova', 'Montenegro', 'Netherlands', 'North Macedonia ',
#        'Norway', 'Poland', 'Portugal', 'Romania', 'Russian Federation',
#        'Spain', 'Sweden', 'Switzerland', 'Türkiye, Republic of', 'Ukraine'],
#       dtype='object', name='country')

# %%
# show inflation rate for the list of countries
chosen_countries = ['Germany']


plt.figure(figsize=(12, 8))

for country in chosen_countries:
    plt.plot(inflation.columns, inflation.loc[country], linewidth=3)


plt.xlabel('Year')
plt.ylabel('Inflation Rate')
plt.title('Inflation Rate Over Years for Germany')
plt.legend(title='Country')



plt.xticks(rotation=45)

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
inflation = inflation.iloc[:, :-6]

# %%
inflation
# Out:
#                         2013  2014  2015  2016  2017  2018  2019  2020  2021  \
# country
# Albania                  1.9   1.6   1.9   1.3   2.0   2.0   1.4   1.6   2.0
# Austria                  2.1   1.5   0.8   1.0   2.2   2.1   1.5   1.4   2.8
# Belarus                 18.3  18.1  13.5  11.8   6.0   4.9   5.6   5.5   9.5
# Belgium                  1.2   0.5   0.6   1.8   2.2   2.3   1.3   0.4   3.2
# Bosnia and Herzegovina  -0.1  -0.9  -1.0  -1.6   0.8   1.4   0.6  -1.1   2.0
# Bulgaria                 0.4  -1.6  -1.1  -1.3   1.2   2.6   2.5   1.2   2.8
# Croatia                  2.3   0.2  -0.3  -0.6   1.3   1.6   0.8   0.0   2.7
# Cyprus                   0.4  -0.3  -1.5  -1.2   0.7   0.8   0.6  -1.1   2.2
# Czech Republic           1.4   0.3   0.3   0.7   2.5   2.1   2.8   3.2   3.8
# Denmark                  0.5   0.4   0.2   0.0   1.1   0.7   0.7   0.3   1.9
# Estonia                  3.2   0.5   0.1   0.8   3.7   3.4   2.3  -0.6   4.5
# ...

# %%
chosen_countries=["Germany"]
# Combining the plots(inflation and expences)
fig, ax1 = plt.subplots(figsize=(12, 8))

#plotting
ax1.bar(expences_germany_2022['Year'].astype(str), expences_germany_2022['Billion Euros'], color='lightgreen')
ax1.set_xlabel('Year')
ax1.set_ylabel('Share of organic food sales relative to all food sales in Germany (%)')
#ax1.set_title('Bio food market share in Germany until 2022 in percent')
ax1.grid(True)
ax1.tick_params(axis='x', rotation=45)

# Adding the line chart
ax2 = ax1.twinx()
for country in chosen_countries:
    ax2.plot(inflation.columns, inflation.loc[country], label=country, linewidth=3 , marker='o')
ax2.set_ylabel('Inflation rate in Germany (%)')
#ax2.legend(title='Country')

# Showing plots together
plt.tight_layout()
plt.show()

# %%
chosen_countries=["Germany"]
# Combining the plots (different colors)
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plotting the bar chart on primary y-axis
ax1.bar(expences_germany_2022['Year'].astype(str), expences_germany_2022['Billion Euros'], color='#329529')
ax1.set_xlabel('Year', fontsize=16)
ax1.set_ylabel('Share of organic food sales relative to all food sales in Germany (%)')
#ax1.set_title('Bio food market share in Germany until 2022 in percent')
ax1.grid(False)
ax1.tick_params(axis='x', rotation=45)

# Adding the line chart on secondary y-axis
ax2 = ax1.twinx()
for country in chosen_countries:
    ax2.plot(inflation.columns, inflation.loc[country], label=country, linewidth=4, color="#1F43A9", marker="o")
ax2.set_ylabel('Inflation rate in Germany (%)')
#ax2.legend(title='Country')

# Showing the combined plot
plt.tight_layout() 
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 8))

# plot
ax1.bar(expences_germany_2022['Year'].astype(str), expences_germany_2022['Billion Euros'], color='#329529')
ax1.set_xlabel('Year', fontsize=15)  # Increase font size
ax1.set_ylabel('Share of organic food sales relative to all food sales (%)', fontsize=16)  # Increase font size
ax1.grid(False)
ax1.tick_params(axis='x', rotation=45, labelsize=14)  # Increase font size for x-axis labels

# Adding the line chart
ax2 = ax1.twinx()
for country in chosen_countries:
    ax2.plot(inflation.columns, inflation.loc[country], label=country, linewidth=3, color="#1F43A9", marker="o" )
ax2.set_ylabel('Inflation rate in Germany (%)', fontsize=16)  # Increase font size
ax2.tick_params(axis='y', labelsize=14)  # Increase font size for y-axis labels
#ax2.legend(title='Country', fontsize=14, title_fontsize=14)  # Increase font size for legend


plt.tight_layout()
plt.show()
