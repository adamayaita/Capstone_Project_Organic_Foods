# %%
import requests as r
import pandas as pd
import sqlalchemy

# %%
laying_hens = pd.read_csv('Laying_Hens_Europe.csv', header=[1], skiprows=[0], delimiter=';')

# %%
laying_hens
# Out:
#      Country  Year Not enriched cage Enriched cage Free range       Barn  \
# 0    Austria  2011                 0       230.274  1.122.434  3.791.357
# 1        NaN  2012                 0       242.982  1.167.650  3.924.597
# 2        NaN  2013                 0       185.382  1.128.111  4.071.532
# 3        NaN  2014                 0       129.942  1.181.396  4.162.500
# 4        NaN  2015                 0       129.942  1.265.350  4.263.193
# ..       ...   ...               ...           ...        ...        ...
# 292      NaN  2017               NaN       988.488    244.461  5.474.563
# 293      NaN  2018               NaN       799.992    271.205  6.211.042
# 294      NaN  2019               NaN       745.652    271.205  6.442.519
# 295      NaN  2020               NaN       482.200    324.738  6.640.196
# 296      NaN  2021               NaN       324.040    425.608  6.668.661
#
#        Organic      Total  Unnamed: 8 Country.1  Year.1 Not enriched cage.1  \
# ...

# %%
#laying_hens = laying_hens.dropna(axis=0, how='all')

# %%
#laying_hens.reset_index(drop=True, inplace=True)

# %%
#laying_hens['Country'].iloc[1]=laying_hens['Country'].iloc[0]

# %%
for i in range (1, 11): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[0]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3629180804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (1, 11): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[0]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3629180804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (1, 11): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[0]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3629180804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
laying_hens.head(15)
# Out:
#     Country  Year Not enriched cage Enriched cage Free range       Barn  \
# 0   Austria  2011                 0       230.274  1.122.434  3.791.357
# 1   Austria  2012                 0       242.982  1.167.650  3.924.597
# 2   Austria  2013                 0       185.382  1.128.111  4.071.532
# 3   Austria  2014                 0       129.942  1.181.396  4.162.500
# 4   Austria  2015                 0       129.942  1.265.350  4.263.193
# 5   Austria  2016               NaN       129.942  1.404.792  4.304.921
# 6   Austria  2017               NaN        61.622  1.499.623  4.377.351
# 7   Austria  2018               NaN        57.328  1.605.622  4.383.767
# 8   Austria  2019               NaN        17.280  1.731.302  4.330.951
# 9   Austria  2020               NaN             0  1.884.864  4.342.068
# 10  Austria  2021               NaN             0  2.105.242  4.343.647
# 11  Belgium  2011         5.545.000     1.100.000        688  1.652.000
# ...

# %%
for i in range (12, 22): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[11]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3089768379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (12, 22): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[11]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3089768379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (12, 22): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[11]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3089768379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
laying_hens.head(30)
# Out:
#      Country  Year Not enriched cage Enriched cage Free range       Barn  \
# 0    Austria  2011                 0       230.274  1.122.434  3.791.357
# 1    Austria  2012                 0       242.982  1.167.650  3.924.597
# 2    Austria  2013                 0       185.382  1.128.111  4.071.532
# 3    Austria  2014                 0       129.942  1.181.396  4.162.500
# 4    Austria  2015                 0       129.942  1.265.350  4.263.193
# 5    Austria  2016               NaN       129.942  1.404.792  4.304.921
# 6    Austria  2017               NaN        61.622  1.499.623  4.377.351
# 7    Austria  2018               NaN        57.328  1.605.622  4.383.767
# 8    Austria  2019               NaN        17.280  1.731.302  4.330.951
# 9    Austria  2020               NaN             0  1.884.864  4.342.068
# 10   Austria  2021               NaN             0  2.105.242  4.343.647
# 11   Belgium  2011         5.545.000     1.100.000        688  1.652.000
# ...

# %%
for i in range (23, 33): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc
.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (221, 231): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[220]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1956316138.py:1: SettingWithCopyWarning:
# ...

# %%
for i in range (232, 242): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[231]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1353480719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (232, 242): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[231]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1353480719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (232, 242): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[231]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1353480719.py:1: SettingWithCopyWarning:
# ...

# %%
for i in range (243, 253): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[242]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/851922534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (243, 253): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[242]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/851922534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (243, 253): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[242]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/851922534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range (254, 264): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[253]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/448089739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (254, 264): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[253]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/448089739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (254, 264): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[253]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/448089739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range (265, 275): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[264]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1814837975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (265, 275): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[264]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1814837975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (265, 275): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[264]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1814837975.py:1: SettingWithCopyWarning:
# ...

# %%
for i in range (276, 286): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[275]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1141994963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (276, 286): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[275]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1141994963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (276, 286): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[275]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/1141994963.py:1: SettingWithCopyWarning:
# ...

# %%
for i in range (287, 297): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[286]
# Out:
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3181746096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (287, 297): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[286]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3181746096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for i in range (287, 297): laying_hens['Country'].iloc[i]=laying_hens['Country'].iloc[286]
# /var/folders/wq/85_dxp_965d1mz8jcysmxbs80000gn/T/ipykernel_1076/3181746096.py:1: SettingWithCopyWarning:
# ...

# %%
laying_hens.tail(40)
# Out:
#       Country  Year Not enriched cage Enriched cage Free range       Barn  \
# 257  Slovakia  2015                 0     2.665.517     19.880    359.528
# 258  Slovakia  2016               NaN     2.696.957     20.280    356.328
# 259  Slovakia  2017               NaN     2.601.903     23.280    447.608
# 260  Slovakia  2018               NaN     2.691.154     29.192    504.252
# 261  Slovakia  2019               NaN     2.570.002     34.639    476.928
# 262  Slovakia  2020               NaN     2.420.902     67.706    661.044
# 263  Slovakia  2021               NaN     2.354.022     69.592    697.119
# 264  Slovenia  2011               NaN           NaN        NaN        NaN
# 265  Slovenia  2012               NaN       667.240     13.052    779.509
# 266  Slovenia  2013                 0       687.100     16.416    757.001
# 267  Slovenia  2014                 0       687.100     16.240    744.656
# 268  Slovenia  2015                 0       685.660     12.894    606.088
# ...

# %%
laying_hens = laying_hens.drop(columns=['Unnamed: 8', 'Country.1'])

# %%
laying_hens
# Out:
#      Country  Year Not enriched cage Enriched cage Free range       Barn  \
# 0    Austria  2011                 0       230.274  1.122.434  3.791.357
# 1    Austria  2012                 0       242.982  1.167.650  3.924.597
# 2    Austria  2013                 0       185.382  1.128.111  4.071.532
# 3    Austria  2014                 0       129.942  1.181.396  4.162.500
# 4    Austria  2015                 0       129.942  1.265.350  4.263.193
# ..       ...   ...               ...           ...        ...        ...
# 292   Sweden  2017               NaN       988.488    244.461  5.474.563
# 293   Sweden  2018               NaN       799.992    271.205  6.211.042
# 294   Sweden  2019               NaN       745.652    271.205  6.442.519
# 295   Sweden  2020               NaN       482.200    324.738  6.640.196
# 296   Sweden  2021               NaN       324.040    425.608  6.668.661
#
#        Organic      Total  Year.1 Not enriched cage.1 Enriched cage.1  \
# ...

# %%
laying_hens = laying_hens.drop(columns=['Not enriched cage', 'Not enriched cage.1',])

# %%
laying_hens
# Out:
#      Country  Year Enriched cage Free range       Barn    Organic      Total  \
# 0    Austria  2011       230.274  1.122.434  3.791.357    538.209  5.682.274
# 1    Austria  2012       242.982  1.167.650  3.924.597    566.548  5.901.777
# 2    Austria  2013       185.382  1.128.111  4.071.532    577.296  5.962.321
# 3    Austria  2014       129.942  1.181.396  4.162.500    580.049  6.053.887
# 4    Austria  2015       129.942  1.265.350  4.263.193    674.652  6.333.137
# ..       ...   ...           ...        ...        ...        ...        ...
# 292   Sweden  2017       988.488    244.461  5.474.563  1.353.469  8.060.981
# 293   Sweden  2018       799.992    271.205  6.211.042  1.396.980  8.679.219
# 294   Sweden  2019       745.652    271.205  6.442.519  1.442.545  8.901.921
# 295   Sweden  2020       482.200    324.738  6.640.196  1.278.515  8.725.649
# 296   Sweden  2021       324.040    425.608  6.668.661  1.236.888  8.655.197
#
# ...

# %%
laying_hens.query('Country =="Austria" & Year==2011')
# Out:
#    Country  Year Enriched cage Free range       Barn  Organic      Total  \
# 0  Austria  2011       230.274  1.122.434  3.791.357  538.209  5.682.274
#
#   Enriched cage.1 Free range.1  Barn.1 Organic.1  Total.1
# 0           4,1 %       19,8 %  66,7 %     9,5 %  100,0 %

# %%
laying_hens_freerange= laying_hens.copy()

# %%
laying_hens_freerange=laying_hens_freerange.rename(columns={'Free range': 'quantity','Free range.1': 'quantity.1'})

# %%
laying_hens_freerange['product_category']= 'Free range'

# %%
laying_hens_freerange = laying_hens_freerange.drop(columns=['Barn', 'Organic', 'Total', 'Enriched cage', 'Enriched cage.1', 'Barn.1', 'Organic.1', 'Total.1'])

# %%
laying_hens_freerange
# Out:
#      Country  Year   quantity quantity.1 product_category
# 0    Austria  2011  1.122.434     19,8 %       Free range
# 1    Austria  2012  1.167.650     19,8 %       Free range
# 2    Austria  2013  1.128.111     18,9 %       Free range
# 3    Austria  2014  1.181.396     19,5 %       Free range
# 4    Austria  2015  1.265.350     20,0 %       Free range
# ..       ...   ...        ...        ...              ...
# 292   Sweden  2017    244.461      3,0 %       Free range
# 293   Sweden  2018    271.205      3,1 %       Free range
# 294   Sweden  2019    271.205      3,0 %       Free range
# 295   Sweden  2020    324.738      3,7 %       Free range
# 296   Sweden  2021    425.608      4,9 %       Free range
#
# [248 rows x 5 columns]

# %%
laying_hens_enriched_cage = laying_hens.copy()

# %%
laying_hens_enriched_cage=laying_hens_enriched_cage.rename(columns={'Enriched cage': 'quantity','Enriched cage.1': 'quantity.1'})

# %%
laying_hens_enriched_cage['product_category']= 'Enriched cage'

# %%
laying_hens_enriched_cage = laying_hens_enriched_cage.drop(columns=['Barn', 'Organic', 'Total', 'Free range', 'Free range.1', 'Barn.1', 'Organic.1', 'Total.1'])

# %%
laying_hens_enriched_cage
# Out:
#      Country  Year quantity quantity.1 product_category
# 0    Austria  2011  230.274      4,1 %    Enriched cage
# 1    Austria  2012  242.982      4,1 %    Enriched cage
# 2    Austria  2013  185.382      3,1 %    Enriched cage
# 3    Austria  2014  129.942      2,1 %    Enriched cage
# 4    Austria  2015  129.942      2,1 %    Enriched cage
# ..       ...   ...      ...        ...              ...
# 292   Sweden  2017  988.488     12,3 %    Enriched cage
# 293   Sweden  2018  799.992      9,2 %    Enriched cage
# 294   Sweden  2019  745.652      8,4 %    Enriched cage
# 295   Sweden  2020  482.200      5,5 %    Enriched cage
# 296   Sweden  2021  324.040      3,7 %    Enriched cage
#
# [248 rows x 5 columns]

# %%
laying_hens_barn = laying_hens.copy()

# %%
laying_hens_barn = laying_hens_barn.rename(columns={'Barn': 'quantity','Barn.1': 'quantity.1'})

# %%
laying_hens_barn['product_category']= 'Barn'

# %%
laying_hens_barn = laying_hens_barn.drop(columns=['Enriched cage', 'Organic', 'Total', 'Free range', 'Free range.1', 'Enriched cage.1', 'Organic.1', 'Total.1'])

# %%
laying_hens_barn
# Out:
#      Country  Year   quantity quantity.1 product_category
# 0    Austria  2011  3.791.357     66,7 %             Barn
# 1    Austria  2012  3.924.597     66,5 %             Barn
# 2    Austria  2013  4.071.532     68,3 %             Barn
# 3    Austria  2014  4.162.500     68,8 %             Barn
# 4    Austria  2015  4.263.193     67,3 %             Barn
# ..       ...   ...        ...        ...              ...
# 292   Sweden  2017  5.474.563     67,9 %             Barn
# 293   Sweden  2018  6.211.042     71,6 %             Barn
# 294   Sweden  2019  6.442.519     72,4 %             Barn
# 295   Sweden  2020  6.640.196     76,1 %             Barn
# 296   Sweden  2021  6.668.661     77,0 %             Barn
#
# [248 rows x 5 columns]

# %%
laying_hens_organic = laying_hens.copy()

# %%
laying_hens_organic = laying_hens_organic.rename(columns={'Organic': 'quantity','Organic.1': 'quantity.1'})

# %%
laying_hens_organic['product_category']= 'Organic'

# %%
laying_hens_organic = laying_hens_organic.drop(columns=['Enriched cage', 'Barn', 'Total', 'Free range', 'Free range.1', 'Enriched cage.1', 'Barn.1', 'Total.1'])

# %%
laying_hens_organic
# Out:
#      Country  Year   quantity quantity.1 product_category
# 0    Austria  2011    538.209      9,5 %          Organic
# 1    Austria  2012    566.548      9,6 %          Organic
# 2    Austria  2013    577.296      9,7 %          Organic
# 3    Austria  2014    580.049      9,6 %          Organic
# 4    Austria  2015    674.652     10,7 %          Organic
# ..       ...   ...        ...        ...              ...
# 292   Sweden  2017  1.353.469     16,8 %          Organic
# 293   Sweden  2018  1.396.980     16,1 %          Organic
# 294   Sweden  2019  1.442.545     16,2 %          Organic
# 295   Sweden  2020  1.278.515     14,7 %          Organic
# 296   Sweden  2021  1.236.888     14,3 %          Organic
#
# [248 rows x 5 columns]

# %%
concatenated_laying_hens = pd.concat([laying_hens_freerange, laying_hens_enriched_cage, laying_hens_barn, laying_hens_organic])

# %%
concatenated_laying_hens.reset_index(drop=True, inplace=True)

# %%
concatenated_laying_hens
# Out:
#      Country  Year   quantity quantity.1 product_category
# 0    Austria  2011  1.122.434     19,8 %       Free range
# 1    Austria  2012  1.167.650     19,8 %       Free range
# 2    Austria  2013  1.128.111     18,9 %       Free range
# 3    Austria  2014  1.181.396     19,5 %       Free range
# 4    Austria  2015  1.265.350     20,0 %       Free range
# ..       ...   ...        ...        ...              ...
# 987   Sweden  2017  1.353.469     16,8 %          Organic
# 988   Sweden  2018  1.396.980     16,1 %          Organic
# 989   Sweden  2019  1.442.545     16,2 %          Organic
# 990   Sweden  2020  1.278.515     14,7 %          Organic
# 991   Sweden  2021  1.236.888     14,3 %          Organic
#
# [992 rows x 5 columns]

# %%
concatenated_laying_hens.head(40)
# Out:
#      Country  Year   quantity quantity.1 product_category
# 0    Austria  2011  1.122.434     19,8 %       Free range
# 1    Austria  2012  1.167.650     19,8 %       Free range
# 2    Austria  2013  1.128.111     18,9 %       Free range
# 3    Austria  2014  1.181.396     19,5 %       Free range
# 4    Austria  2015  1.265.350     20,0 %       Free range
# 5    Austria  2016  1.404.792     21,4 %       Free range
# 6    Austria  2017  1.499.623     22,3 %       Free range
# 7    Austria  2018  1.605.622     23,5 %       Free range
# 8    Austria  2019  1.731.302     25,0 %       Free range
# 9    Austria  2020  1.884.864     26,5 %       Free range
# 10   Austria  2021  2.105.242     28,4 %       Free range
# 11   Belgium  2011        688      0,0 %       Free range
# 12   Belgium  2012    800.000      8,7 %       Free range
# 13   Belgium  2013    869.130     10,3 %       Free range
# 14   Belgium  2014  2.265.741     26,8 %       Free range
# ...

# %%
concatenated_laying_hens.tail(40)
# Out:
#       Country  Year   quantity quantity.1 product_category
# 952  Slovakia  2014      9.321      0,3 %          Organic
# 953  Slovakia  2015      5.334      0,2 %          Organic
# 954  Slovakia  2016      5.334      0,2 %          Organic
# 955  Slovakia  2017      5.334      0,2 %          Organic
# 956  Slovakia  2018      5.934      0,2 %          Organic
# 957  Slovakia  2019      5.334      0,2 %          Organic
# 958  Slovakia  2020      5.334      0,2 %          Organic
# 959  Slovakia  2021      5.334      0,2 %          Organic
# 960  Slovenia  2012      6.380      0,4 %          Organic
# 961  Slovenia  2013      6.559      0,4 %          Organic
# 962  Slovenia  2014      6.429      0,4 %          Organic
# 963  Slovenia  2015     13.537      1,0 %          Organic
# 964  Slovenia  2016     24.015      2,1 %          Organic
# 965  Slovenia  2017     24.336      2,0 %          Organic
# 966  Slovenia  2018     35.966      2,4 %          Organic
# ...

# %%
import sql_functions as sqlf

# %%
engine = sqlf.get_engine()

# %%
schema='capstone_organicfood'
table_name = 'concatenated_laying_hens'

# %%
import psycopg2

# %%
# Write records stored in the dataframe to SQL database:
if engine!=None:
    try:
        concatenated_laying_hens.to_sql(name=table_name, # name of SQL table variable
                        con=engine, # engine or connection
                        schema=schema, # our class schema variable
                        if_exists='replace', # Drop the table before inserting new values
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The concatenated_laying_hens table was imported successfully.
