# %%
# Import requests package:
import requests

# %%
# Set URL as url:
url = 'https://www.ec.europa.eu/agrifood/api/poultry/egg/prices?'

# %%
# Create parameter dictionary:
parameters = {
    'beginDate': '01/01/2021',
    'endDate': '22/01/2024'}

# %%
# Send get request and save in variable r:
r = requests.get(url, parameters)

# Print result:
print(r)
# Out:
# <Response [200]>

# %%
# Print headers:
r.headers
# Out:
# {'Date': 'Mon, 12 Feb 2024 13:59:01 GMT', 'Content-Type': 'application/json', 'Server': 'Europa', 'Connection': 'close', 'Content-Encoding': 'gzip'}

# %%
# Print cookies:
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
# Print encoding:
r.encoding
# Out:
# 'utf-8'

# %%
# Apply JSON decoder and save in prices_eggs_prelim:
prices_eggs_prelim = r.json()

# Print prices_eggs_prelim:
prices_eggs_prelim
# Out:
# [{'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€334.49',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€515.04',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€266.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€292.47',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€327.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€255.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€205.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€251.82',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€290.33',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€231.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€277.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€260.57',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€364.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€203.44',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€183.16',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€345.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€273.20',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€260.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€512.17',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€222.64',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€374.93',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€207.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€243.47',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€383.04',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€244.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€537.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€233.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€265.52',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€239.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€231.25',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€273.45',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€436.51',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€248.41',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€282.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€240.24',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€275.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€199.62',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€431.12',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€170.20',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€271.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€304.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€213.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€244.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€323.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€220.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€322.43',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€271.64',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€396.26',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€230.38',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€192.26',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€290.75',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€364.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€216.49',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€276.72',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€199.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€277.77',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€396.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€253.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€360.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€210.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€330.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€193.36',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€210.25',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€240.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€276.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€359.28',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€240.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€334.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€266.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€511.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€247.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€301.19',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€324.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€207.56',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€227.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€305.93',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€236.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€270.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€273.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€364.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€188.20',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€176.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€258.36',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€337.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€501.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€281.05',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€223.29',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€208.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€369.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€244.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€383.84',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€245.97',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€537.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€233.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€269.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€241.26',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€436.88',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€274.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€231.72',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€248.41',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€282.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€301.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€216.39',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€201.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€173.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€457.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€304.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€271.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€245.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€323.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€213.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€228.71',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€268.71',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€392.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€325.55',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€234.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€214.52',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€191.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€367.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€290.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€200.27',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€293.47',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€272.01',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€406.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€226.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€241.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€426.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€240.54',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€212.24',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€195.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€330.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€245.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€363.41',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€284.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€518.39',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€268.42',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€337.54',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€357.88',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€301.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€263.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€209.89',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€225.43',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€230.32',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€238.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€289.66',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€265.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€364.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€202.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€176.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€334.09',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€454.12',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€255.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€273.29',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€209.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€222.94',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€375.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€244.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€381.45',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€246.34',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€537.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€233.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€245.54',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€267.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€274.89',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€436.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€232.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€251.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€285.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€280.25',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€198.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€236.34',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€430.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€174.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€187.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€304.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€271.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€324.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€246.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€214.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€275.32',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€392.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€322.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€230.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€234.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€215.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€340.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€252.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€191.40',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€205.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€295.74',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€390.69',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€235.66',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€395.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€240.38',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€201.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€329.43',
# ...
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€297.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€204.96',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€250.74',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€199.48',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€279.77',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€185.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€271.22',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€283.29',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€425.40',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€174.08',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€189.43',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€431.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€262.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€237.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€226.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€377.32',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€209.98',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€223.19',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€210.89',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€500.01',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€381.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€233.68',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€238.08',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€261.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€230.74',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€272.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€436.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€231.51',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€252.38',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€286.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€207.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€230.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€273.98',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€510.87',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€186.48',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€212.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€237.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€285.97',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€235.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€313.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€203.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€263.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€384.06',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€310.95',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€216.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€234.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€357.44',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€295.45',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€184.36',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€213.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€218.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€262.97',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€289.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€400.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€229.92',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€408.62',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€241.62',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€196.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€221.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€240.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€344.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€266.37',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€233.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '16/10/2023',
#   'endDate': '22/10/2023',
#   'price': '€514.77',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '16/10/2023',
#   'endDate': '22/10/2023',
#   'price': '€340.57',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  ...]

# %%
# Print type of prices_eggs_prelim:
type(prices_eggs_prelim)
# Out:
# list

# %%
# Import pandas package:
import pandas as pd

# Transform list to dataframe:
prices_eggs = pd.DataFrame(prices_eggs_prelim)

# %%
# Show dataframe:
prices_eggs
# Out:
#         beginDate     endDate    price     unit farmingMethod  marketingYear  \
# 0      15/01/2024  21/01/2024  €334.49  €/100Kg    Free range           2024
# 1      15/01/2024  21/01/2024  €515.04  €/100Kg       Organic           2024
# 2      15/01/2024  21/01/2024  €266.79  €/100Kg          Barn           2024
# 3      15/01/2024  21/01/2024  €292.47  €/100Kg    Free range           2024
# 4      15/01/2024  21/01/2024  €327.15  €/100Kg       Organic           2024
# ...           ...         ...      ...      ...           ...            ...
# 11757  04/01/2021  10/01/2021  €154.31  €/100Kg          Cage           2021
# 11758  04/01/2021  10/01/2021   €88.64  €/100Kg          Cage           2021
# 11759  04/01/2021  10/01/2021  €310.10  €/100Kg       Organic           2021
# 11760  04/01/2021  10/01/2021  €218.24  €/100Kg    Free range           2021
# 11761  04/01/2021  10/01/2021  €179.96  €/100Kg          Barn           2021
#
#       memberStateCode memberStateName
# 0                  AT         Austria
# 1                  AT         Austria
# 2                  AT         Austria
# 3                  BE         Belgium
# 4                  BE         Belgium
# ...               ...             ...
# 11757              SI        Slovenia
# 11758              ES           Spain
# 11759              SE          Sweden
# 11760              SE          Sweden
# 11761              SE          Sweden
#
# [11762 rows x 8 columns]

# %%
# Show dataframe info:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   beginDate        11762 non-null  object
#  1   endDate          11762 non-null  object
#  2   price            11762 non-null  object
#  3   unit             11762 non-null  object
#  4   farmingMethod    11762 non-null  object
#  5   marketingYear    11762 non-null  int64
#  6   memberStateCode  11762 non-null  object
#  7   memberStateName  11762 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 735.2+ KB

# %%
# It appears that there are no null values.
# However, it is possible that there are null values that are not specified as such (and that are instead indicated with
# certain characters such as "." or similar).
# In order to check this, we first list the unique values of the variables that have only a limited number of values:

# %%
prices_eggs.unit.unique()
# Out:
# array(['€/100Kg'], dtype=object)

# %%
prices_eggs.farmingMethod.unique()
# Out:
# array(['Free range', 'Organic', 'Barn', 'Cage'], dtype=object)

# %%
prices_eggs.marketingYear.unique()
# Out:
# array([2024, 2023, 2022, 2021])

# %%
prices_eggs.memberStateCode.unique()
# Out:
# array(['AT', 'BE', 'BG', 'HR', 'CY', 'CZ', 'EE', 'FI', 'FR', 'DE', 'EL',
#        'HU', 'IE', 'IT', 'LV', 'LT', 'MT', 'NL', 'PL', 'PT', 'RO', 'SK',
#        'SI', 'ES', 'SE', 'DK'], dtype=object)

# %%
prices_eggs.memberStateName.unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia',
#        'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Malta', 'Netherlands',
#        'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain',
#        'Sweden', 'Denmark'], dtype=object)

# %%
# For beginDate, endDate, and price, we sort the data by the respective variable and show the first and last
# cases in order to find out whether there are null values that are not specified as such:

# %%
prices_eggs[['beginDate']].sort_values(by='beginDate',ascending=True).head()
# Out:
#       beginDate
# 188  01/01/2024
# 210  01/01/2024
# 209  01/01/2024
# 208  01/01/2024
# 207  01/01/2024

# %%
prices_eggs[['beginDate']].sort_values(by='beginDate',ascending=True).tail()
# Out:
#        beginDate
# 4971  31/10/2022
# 4970  31/10/2022
# 4969  31/10/2022
# 4938  31/10/2022
# 4917  31/10/2022

# %%
prices_eggs[['endDate']].sort_values(by='endDate',ascending=True).head()
# Out:
#          endDate
# 4353  01/01/2023
# 4361  01/01/2023
# 4362  01/01/2023
# 4363  01/01/2023
# 4364  01/01/2023

# %%
prices_eggs[['endDate']].sort_values(by='endDate',ascending=True).tail()
# Out:
#         endDate
# 284  31/12/2023
# 285  31/12/2023
# 286  31/12/2023
# 279  31/12/2023
# 231  31/12/2023

# %%
prices_eggs[['price']].sort_values(by='price',ascending=True).head()
# Out:
#          price
# 9648   €100.23
# 10827  €100.24
# 11535  €100.25
# 9281   €100.43
# 9753   €100.53

# %%
prices_eggs[['price']].sort_values(by='price',ascending=True).tail()
# Out:
#         price
# 11491  €99.22
# 10104  €99.31
# 10670  €99.36
# 10209  €99.55
# 9935   €99.58

# %%
# We conclude that there are no null values in the dataframe.

# %%
# Show variables:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   beginDate        11762 non-null  object
#  1   endDate          11762 non-null  object
#  2   price            11762 non-null  object
#  3   unit             11762 non-null  object
#  4   farmingMethod    11762 non-null  object
#  5   marketingYear    11762 non-null  int64
#  6   memberStateCode  11762 non-null  object
#  7   memberStateName  11762 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 735.2+ KB

# %%
# We do not need the marketingYear variable, especially as we do not know its exact relationship with beginDate and endDate:
prices_eggs = prices_eggs.drop(['marketingYear'], axis=1)

# We do not need the unit variable, as we know that prices are measured in €/100kg:
prices_eggs = prices_eggs.drop(['unit'], axis=1)

# Rename variable names to standard format and to names we can easily work with:
prices_eggs = prices_eggs.rename(columns={'beginDate': 'begin_date'})
prices_eggs = prices_eggs.rename(columns={'endDate': 'end_date'})
prices_eggs = prices_eggs.rename(columns={'farmingMethod': 'farming_method'})
prices_eggs = prices_eggs.rename(columns={'memberStateCode': 'country_code'})
prices_eggs = prices_eggs.rename(columns={'memberStateName': 'country'})

# Show variables again:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   begin_date      11762 non-null  object
#  1   end_date        11762 non-null  object
#  2   price           11762 non-null  object
#  3   farming_method  11762 non-null  object
#  4   country_code    11762 non-null  object
#  5   country         11762 non-null  object
# dtypes: object(6)
# memory usage: 551.5+ KB

# %%
# Remove the € symbol in the price values:
prices_eggs['price'] = prices_eggs['price'].str.replace('€', '')

# Check results:
prices_eggs
# Out:
#        begin_date    end_date   price farming_method country_code   country
# 0      15/01/2024  21/01/2024  334.49     Free range           AT   Austria
# 1      15/01/2024  21/01/2024  515.04        Organic           AT   Austria
# 2      15/01/2024  21/01/2024  266.79           Barn           AT   Austria
# 3      15/01/2024  21/01/2024  292.47     Free range           BE   Belgium
# 4      15/01/2024  21/01/2024  327.15        Organic           BE   Belgium
# ...           ...         ...     ...            ...          ...       ...
# 11757  04/01/2021  10/01/2021  154.31           Cage           SI  Slovenia
# 11758  04/01/2021  10/01/2021   88.64           Cage           ES     Spain
# 11759  04/01/2021  10/01/2021  310.10        Organic           SE    Sweden
# 11760  04/01/2021  10/01/2021  218.24     Free range           SE    Sweden
# 11761  04/01/2021  10/01/2021  179.96           Barn           SE    Sweden
#
# [11762 rows x 6 columns]

# %%
# Transform begin_date and end_date to datetime format:
prices_eggs['begin_date'] = pd.to_datetime(prices_eggs['begin_date'], format='%d/%m/%Y')
prices_eggs['end_date'] = pd.to_datetime(prices_eggs['end_date'], format='%d/%m/%Y')

# Transform price to float:
prices_eggs['price'] = prices_eggs['price'].astype(float)

# Check results:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   begin_date      11762 non-null  datetime64[ns]
#  1   end_date        11762 non-null  datetime64[ns]
#  2   price           11762 non-null  float64
#  3   farming_method  11762 non-null  object
#  4   country_code    11762 non-null  object
#  5   country         11762 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 551.5+ KB

# %%
# In order to calculate weighted averages of prices in the EU,
# we need to merge data about the population share of each country in each year.

# %%
# Read in csv file containing data about populations:
population = pd.read_csv('data/population_eu_countries.csv')

# %%
# Show dataframe:
population
# Out:
#     country_code   country  year   population  population_share
# 0             BE   Belgium  2021   11,554,767            0.0260
# 1             BE   Belgium  2022   11,617,623            0.0261
# 2             BE   Belgium  2023   11,754,004            0.0263
# 3             BE   Belgium  2024   11,754,004            0.0263
# 4             BG  Bulgaria  2021    6,916,548            0.0155
# ..           ...       ...   ...          ...               ...
# 103           SE    Sweden  2024   10,521,556            0.0236
# 104          sum     total  2021  445,094,922            1.0000
# 105          sum     total  2022  444,806,786            1.0000
# 106          sum     total  2023  446,410,586            1.0000
# 107          sum     total  2024  446,410,586            1.0000
#
# [108 rows x 5 columns]

# %%
# Create a variable for the year, based on begin_date:
prices_eggs['year'] = prices_eggs['begin_date'].dt.year

# %%
# Check results:
prices_eggs[['begin_date','year']]
# Out:
#       begin_date  year
# 0     2024-01-15  2024
# 1     2024-01-15  2024
# 2     2024-01-15  2024
# 3     2024-01-15  2024
# 4     2024-01-15  2024
# ...          ...   ...
# 11757 2021-01-04  2021
# 11758 2021-01-04  2021
# 11759 2021-01-04  2021
# 11760 2021-01-04  2021
# 11761 2021-01-04  2021
#
# [11762 rows x 2 columns]

# %%
# We merge the population share of each country (identified by country_code) in each year
# to our prices_eggs dataframe:
prices_eggs = pd.merge(prices_eggs, population[['country_code','year','population_share']], on=['country_code','year'], how='left')

# %%
# Check results:
prices_eggs
# Out:
#       begin_date   end_date   price farming_method country_code   country  \
# 0     2024-01-15 2024-01-21  334.49     Free range           AT   Austria
# 1     2024-01-15 2024-01-21  515.04        Organic           AT   Austria
# 2     2024-01-15 2024-01-21  266.79           Barn           AT   Austria
# 3     2024-01-15 2024-01-21  292.47     Free range           BE   Belgium
# 4     2024-01-15 2024-01-21  327.15        Organic           BE   Belgium
# ...          ...        ...     ...            ...          ...       ...
# 11757 2021-01-04 2021-01-10  154.31           Cage           SI  Slovenia
# 11758 2021-01-04 2021-01-10   88.64           Cage           ES     Spain
# 11759 2021-01-04 2021-01-10  310.10        Organic           SE    Sweden
# 11760 2021-01-04 2021-01-10  218.24     Free range           SE    Sweden
# 11761 2021-01-04 2021-01-10  179.96           Barn           SE    Sweden
#
#        year  population_share
# 0      2024            0.0204
# 1      2024            0.0204
# 2      2024            0.0204
# 3      2024            0.0263
# 4      2024            0.0263
# ...     ...               ...
# 11757  2021            0.0047
# 11758  2021            0.1065
# 11759  2021            0.0233
# 11760  2021            0.0233
# 11761  2021            0.0233
#
# [11762 rows x 8 columns]

# %%
# Check results with random samples of cases:
prices_eggs.sample(10)
# Out:
#       begin_date   end_date   price farming_method country_code      country  \
# 11337 2021-02-22 2021-02-28  241.38        Organic           SI     Slovenia
# 10177 2021-06-21 2021-06-27  123.00           Barn           NL  Netherlands
# 10753 2021-04-19 2021-04-25  190.48           Barn           AT      Austria
# 7242  2022-03-28 2022-04-03  332.96        Organic           LV       Latvia
# 11678 2021-01-11 2021-01-17  132.67        Organic           EL       Greece
# 8805  2021-11-01 2021-11-07  203.15     Free range           EE      Estonia
# 9327  2021-09-13 2021-09-19  129.96           Barn           LT    Lithuania
# 5995  2022-07-25 2022-07-31  247.87     Free range           LV       Latvia
# 1396  2023-09-11 2023-09-17  172.91           Cage           CY       Cyprus
# 7516  2022-02-28 2022-03-06  153.79           Cage           EE      Estonia
#
#        year  population_share
# 11337  2021            0.0047
# 10177  2021            0.0393
# 10753  2021            0.0201
# 7242   2022            0.0042
# 11678  2021            0.0240
# 8805   2021            0.0030
# 9327   2021            0.0063
# 5995   2022            0.0042
# 1396   2023            0.0002
# 7516   2022            0.0030

# %%
# We do not need the "year" variable anymore:
prices_eggs = prices_eggs.drop(['year'], axis=1)

# %%
# The weighted average of prices is the sum of the products of weight (i.e., population share) and price.
# Therefore, as the first part of the weighted average of prices,
# we need the products of the population share and the price:
prices_eggs['weight_x_price'] = prices_eggs['population_share'] * prices_eggs['price']

# %%
# Check results:
prices_eggs[['begin_date','end_date','country_code','country','population_share','price','weight_x_price']].sample(10)
# Out:
#       begin_date   end_date country_code   country  population_share   price  \
# 11274 2021-03-01 2021-03-07           SI  Slovenia            0.0047  153.00
# 2074  2023-07-17 2023-07-23           SE    Sweden            0.0236  242.22
# 6310  2022-06-27 2022-07-03           PT  Portugal            0.0233  181.22
# 4098  2023-01-09 2023-01-15           FR    France            0.1525  250.98
# 6902  2022-05-02 2022-05-08           SI  Slovenia            0.0047  402.93
# 6065  2022-07-18 2022-07-24           HU   Hungary            0.0218  162.19
# 2517  2023-06-05 2023-06-11           PT  Portugal            0.0234  469.58
# 10785 2021-04-19 2021-04-25           IE   Ireland            0.0112  143.85
# 11620 2021-01-18 2021-01-24           HU   Hungary            0.0219  122.26
# 5360  2022-09-19 2022-09-25           BE   Belgium            0.0261  293.06
#
#        weight_x_price
# 11274        0.719100
# 2074         5.716392
# 6310         4.222426
# 4098        38.274450
# 6902         1.893771
# 6065         3.535742
# 2517        10.988172
# 10785        1.611120
# 11620        2.677494
# 5360         7.648866

# %%
# For each combination of date and farming_method,
# build the weighted average of EU prices as the sum of the products of weight and price
# (with "reset_index()", we make a dataframe from the results):
prices_eggs_eu = prices_eggs.groupby(['begin_date', 'end_date', 'farming_method'])['weight_x_price'].sum().reset_index()

# Check results:
prices_eggs_eu
# Out:
#     begin_date   end_date farming_method  weight_x_price
# 0   2021-01-04 2021-01-10           Barn       63.419317
# 1   2021-01-04 2021-01-10           Cage       87.260217
# 2   2021-01-04 2021-01-10     Free range      130.828734
# 3   2021-01-04 2021-01-10        Organic      116.811479
# 4   2021-01-11 2021-01-17           Barn       66.583818
# ..         ...        ...            ...             ...
# 631 2024-01-08 2024-01-14        Organic      322.525781
# 632 2024-01-15 2024-01-21           Barn      198.781428
# 633 2024-01-15 2024-01-21           Cage      159.969558
# 634 2024-01-15 2024-01-21     Free range      231.765704
# 635 2024-01-15 2024-01-21        Organic      322.521458
#
# [636 rows x 4 columns]

# %%
# The variable weight_x_price now captures the price in the EU and should therefore be called "price":
prices_eggs_eu = prices_eggs_eu.rename(columns={'weight_x_price': 'price'})

# We add a "country_code" and "country" for the EU values:
prices_eggs_eu['country_code'] = "EU"
prices_eggs_eu['country'] = "European Union"

# Check results:
prices_eggs_eu
# Out:
#     begin_date   end_date farming_method       price country_code  \
# 0   2021-01-04 2021-01-10           Barn   63.419317           EU
# 1   2021-01-04 2021-01-10           Cage   87.260217           EU
# 2   2021-01-04 2021-01-10     Free range  130.828734           EU
# 3   2021-01-04 2021-01-10        Organic  116.811479           EU
# 4   2021-01-11 2021-01-17           Barn   66.583818           EU
# ..         ...        ...            ...         ...          ...
# 631 2024-01-08 2024-01-14        Organic  322.525781           EU
# 632 2024-01-15 2024-01-21           Barn  198.781428           EU
# 633 2024-01-15 2024-01-21           Cage  159.969558           EU
# 634 2024-01-15 2024-01-21     Free range  231.765704           EU
# 635 2024-01-15 2024-01-21        Organic  322.521458           EU
#
#             country
# 0    European Union
# 1    European Union
# 2    European Union
# 3    European Union
# 4    European Union
# ..              ...
# 631  European Union
# 632  European Union
# 633  European Union
# 634  European Union
# 635  European Union
#
# [636 rows x 6 columns]

# %%
# Append the EU data to the country data:
prices_eggs = pd.concat([prices_eggs, prices_eggs_eu])

# Show result:
prices_eggs
# Out:
#     begin_date   end_date       price farming_method country_code  \
# 0   2024-01-15 2024-01-21  334.490000     Free range           AT
# 1   2024-01-15 2024-01-21  515.040000        Organic           AT
# 2   2024-01-15 2024-01-21  266.790000           Barn           AT
# 3   2024-01-15 2024-01-21  292.470000     Free range           BE
# 4   2024-01-15 2024-01-21  327.150000        Organic           BE
# ..         ...        ...         ...            ...          ...
# 631 2024-01-08 2024-01-14  322.525781        Organic           EU
# 632 2024-01-15 2024-01-21  198.781428           Barn           EU
# 633 2024-01-15 2024-01-21  159.969558           Cage           EU
# 634 2024-01-15 2024-01-21  231.765704     Free range           EU
# 635 2024-01-15 2024-01-21  322.521458        Organic           EU
#
#             country  population_share  weight_x_price
# 0           Austria            0.0204        6.823596
# 1           Austria            0.0204       10.506816
# 2           Austria            0.0204        5.442516
# 3           Belgium            0.0263        7.691961
# 4           Belgium            0.0263        8.604045
# ..              ...               ...             ...
# 631  European Union               NaN             NaN
# 632  European Union               NaN             NaN
# 633  European Union               NaN             NaN
# 634  European Union               NaN             NaN
# 635  European Union               NaN             NaN
#
# [12398 rows x 8 columns]

# %%
# We do not need the population_share and weight_x_price variables anymore:
prices_eggs = prices_eggs.drop(['population_share','weight_x_price'], axis=1)

# Show variables:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12398 entries, 0 to 635
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   begin_date      12398 non-null  datetime64[ns]
#  1   end_date        12398 non-null  datetime64[ns]
#  2   price           12398 non-null  float64
#  3   farming_method  12398 non-null  object
#  4   country_code    12398 non-null  object
#  5   country         12398 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 678.0+ KB

# %%
# We now want to calculate relative prices of organic vs. conventional eggs.

# %%
# Show the farming methods:
prices_eggs.farming_method.unique()
# Out:
# array(['Free range', 'Organic', 'Barn', 'Cage'], dtype=object)

# %%
# In the following, we will not consider the farming method "Cage",
# because this farming method does not exist in the data for some countries in the last years
# (e.g., in Germany it does not exist after December 2020).

# %%
# In order to calculate relative prices, we need a separate variable for
# the price of organic eggs, so that we can relate this price to the prices of conventional eggs.

# %%
# Create dataframe specifically for farming method "Organic":
prices_eggs_organic = prices_eggs[prices_eggs['farming_method'] == "Organic"]

# Rename price variable to specify the farming method:
prices_eggs_organic = prices_eggs_organic.rename(columns={'price': 'price_organic'})

# Show dataframe:
prices_eggs_organic
# Out:
#     begin_date   end_date  price_organic farming_method country_code  \
# 1   2024-01-15 2024-01-21     515.040000        Organic           AT
# 4   2024-01-15 2024-01-21     327.150000        Organic           BE
# 14  2024-01-15 2024-01-21     714.900000        Organic           CY
# 21  2024-01-15 2024-01-21     512.170000        Organic           EE
# 23  2024-01-15 2024-01-21     374.930000        Organic           FI
# ..         ...        ...            ...            ...          ...
# 619 2023-12-18 2023-12-24     287.285031        Organic           EU
# 623 2023-12-25 2023-12-31     286.455523        Organic           EU
# 627 2024-01-01 2024-01-07     321.879906        Organic           EU
# 631 2024-01-08 2024-01-14     322.525781        Organic           EU
# 635 2024-01-15 2024-01-21     322.521458        Organic           EU
#
#             country
# 1           Austria
# 4           Belgium
# 14           Cyprus
# 21          Estonia
# 23          Finland
# ..              ...
# 619  European Union
# 623  European Union
# 627  European Union
# 631  European Union
# 635  European Union
#
# [2466 rows x 6 columns]

# %%
# Now we merge the price for organic eggs (for each date and country_code) to the prices_eggs dataframe:
prices_eggs = pd.merge(prices_eggs, prices_eggs_organic[['begin_date','end_date','country_code','price_organic']], on=['begin_date','end_date','country_code'], how='left')

# Show dataframe:
prices_eggs
# Out:
#       begin_date   end_date       price farming_method country_code  \
# 0     2024-01-15 2024-01-21  334.490000     Free range           AT
# 1     2024-01-15 2024-01-21  515.040000        Organic           AT
# 2     2024-01-15 2024-01-21  266.790000           Barn           AT
# 3     2024-01-15 2024-01-21  292.470000     Free range           BE
# 4     2024-01-15 2024-01-21  327.150000        Organic           BE
# ...          ...        ...         ...            ...          ...
# 12599 2024-01-08 2024-01-14  322.525781        Organic           EU
# 12600 2024-01-15 2024-01-21  198.781428           Barn           EU
# 12601 2024-01-15 2024-01-21  159.969558           Cage           EU
# 12602 2024-01-15 2024-01-21  231.765704     Free range           EU
# 12603 2024-01-15 2024-01-21  322.521458        Organic           EU
#
#               country  price_organic
# 0             Austria     515.040000
# 1             Austria     515.040000
# 2             Austria     515.040000
# 3             Belgium     327.150000
# 4             Belgium     327.150000
# ...               ...            ...
# 12599  European Union     322.525781
# 12600  European Union     322.521458
# 12601  European Union     322.521458
# 12602  European Union     322.521458
# 12603  European Union     322.521458
#
# [12604 rows x 7 columns]

# %%
# Relative price of organic eggs in comparison to the farming method shown in the respective row (result in percent):
prices_eggs['price_organic_rel'] = ( prices_eggs['price_organic'] / prices_eggs['price'] ) * 100

# Show results:
prices_eggs
# Out:
#       begin_date   end_date       price farming_method country_code  \
# 0     2024-01-15 2024-01-21  334.490000     Free range           AT
# 1     2024-01-15 2024-01-21  515.040000        Organic           AT
# 2     2024-01-15 2024-01-21  266.790000           Barn           AT
# 3     2024-01-15 2024-01-21  292.470000     Free range           BE
# 4     2024-01-15 2024-01-21  327.150000        Organic           BE
# ...          ...        ...         ...            ...          ...
# 12599 2024-01-08 2024-01-14  322.525781        Organic           EU
# 12600 2024-01-15 2024-01-21  198.781428           Barn           EU
# 12601 2024-01-15 2024-01-21  159.969558           Cage           EU
# 12602 2024-01-15 2024-01-21  231.765704     Free range           EU
# 12603 2024-01-15 2024-01-21  322.521458        Organic           EU
#
#               country  price_organic  price_organic_rel
# 0             Austria     515.040000         153.977697
# 1             Austria     515.040000         100.000000
# 2             Austria     515.040000         193.050714
# 3             Belgium     327.150000         111.857626
# 4             Belgium     327.150000         100.000000
# ...               ...            ...                ...
# 12599  European Union     322.525781         100.000000
# 12600  European Union     322.521458         162.249291
# 12601  European Union     322.521458         201.614271
# 12602  European Union     322.521458         139.158405
# 12603  European Union     322.521458         100.000000
#
# [12604 rows x 8 columns]

# %%
# We now want to upload the dataframe to the database on the server.

# %%
# Import sql_functions.py because we need some functions from that module:
import sql_functions as sqlf

# We need to restart the kernel and rerun at this point if we changed the module since we first imported it.

# %%
# Create a variable called engine using the get_engine function:
engine = sqlf.get_engine()

# %%
# We set the schema to our course name:
schema = 'capstone_organicfood'

# We set table_name to our group name + the name of the dataframe:
table_name = 'prices_eggs'

# %%
# We need psycopg2 for raising possible error message:
import psycopg2

# %%
# Write records stored in dataframe to SQL database:
if engine!=None:
    try:
        prices_eggs.to_sql(name=table_name, # name of SQL table variable
                        con=engine, # engine or connection
                        schema=schema, # our class schema variable
                        if_exists='replace', # Drop the table before inserting new values
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The prices_eggs table was imported successfully.

# %%
# Test: query the newly created table to count the rows (we know from above that the dataframe has 12,604 cases):
sqlf.get_dataframe(f'SELECT COUNT(*) FROM {schema}.prices_eggs;')
# Out:
#    count
# 0  12604

# %%
# Worked!
